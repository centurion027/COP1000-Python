# %%
print ("Hello, COP 1000")
print ("I am learning Python")
print ("This is my first Google Colab notebook.")
# Out:
# Hello, COP 1000
# I am learning Python
# This is my first Google Colab notebook.

# %%
print ("python is running in my browser!")
# Out:
# python is running in my browser!

# %% [markdown]
# My First Pthon Notebook
#
# So far today I have learned how to use colab on Google which I never knew existed before. Additionally I am writing some simple Python code.

# %%
#This is a Python comment
print ("Comments help explain our programs.")
# Out:
# Commends help explain our programs.

# %%
print("Hello, Python!")
# Out:
# Hello, Python!
