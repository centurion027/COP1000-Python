# %% [markdown]
# <a href="https://colab.research.google.com/github/centurion027/COP1000-Python/blob/main/COP1000_Module02_Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercise 1

first_name = "Steven"
age = 39
gpa = 4.0
is_student = True

print(first_name)
print(age)
print(gpa)
print(is_student)

# Exercise 2

print(type(first_name))
print(type(age))
print(type(gpa))
print(type(is_student))

# Exercise 3

score = 75

print(score)

score = 90

print(score)

# Exercise 4

number1 = 20
number2 = 5

print(number1 + number2)
print(number1 - number2)
print(number1 * number2)
print(number1 / number2)

# Exercise 5

last_name = "Lopez"
interest = "Cybersecurity"
print(f"My name is {first_name} {last_name} and I am {age}. I work in the tech space and am interested in getting a {interest} degree to continue my career journey.")

# Exercise 6

name = "Steven Lopez"
course = "COP 1000"
current_grade = 100.0
assignments_completed = 10
currently_enrolled = True

print("Student Record")
print(f"Name: {name}")
print(f"Course: {course}")
print(f"Current Grade: {current_grade}")
print(f"Assignments Completed: {assignments_completed}")
print(f"Currently Enrolled: {currently_enrolled}")
# Out:
# Steven
# 39
# 4.0
# True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 75
# 90
# 25
# 15
# 100
# 4.0
# My name is Steven Lopez and I am 39. I work in the tech space and am interested in getting a Cybersecurity degree to continue my career journey.
# Student Record
# Name: Steven Lopez
# Course: COP 1000
# Current Grade: 100.0
# Assignments Completed: 10
# Currently Enrolled: True
